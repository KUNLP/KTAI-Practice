# %%
# 자소 분리 및 결합 코드
cho_list = ['ㄱ', 'ㄲ', 'ㄴ', 'ㄷ', 'ㄸ', 'ㄹ', 'ㅁ', 'ㅂ', 'ㅃ', 'ㅅ', 'ㅆ', 'ㅇ', 'ㅈ', 'ㅉ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']
jung_list = ['ㅏ', 'ㅐ', 'ㅑ', 'ㅒ', 'ㅓ', 'ㅔ', 'ㅕ', 'ㅖ', 'ㅗ', 'ㅘ', 'ㅙ', 'ㅚ', 'ㅛ', 'ㅜ', 'ㅝ', 'ㅞ', 'ㅟ', 'ㅠ', 'ㅡ', 'ㅢ',
             'ㅣ']
jong_list = ['', 'ㄱ', 'ㄲ', 'ㄳ', 'ㄴ', 'ㄵ', 'ㄶ', 'ㄷ', 'ㄹ', 'ㄺ', 'ㄻ', 'ㄼ', 'ㄽ', 'ㄾ', 'ㄿ', 'ㅀ', 'ㅁ', 'ㅂ', 'ㅄ', 'ㅅ',
             'ㅆ', 'ㅇ', 'ㅈ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']

def jaso_split(korean_word):
    result = []
    for c in list(korean_word.strip()):
        # 현재 문자가 한글일 경우
        if '가' <= c <= '힣':
            chosung = (ord(c) - ord('가')) // 588
            jungsung = ((ord(c) - ord('가')) - (588 * chosung)) // 28
            jongsung = (ord(c) - ord('가')) - (588 * chosung) - (28 * jungsung)
            result.append(cho_list[chosung])
            result.append(jung_list[jungsung])
            if jongsung:
                result.append(jong_list[jongsung])
        # 현재 문자가 한글이 아닐 경우
        else:
            result.append(c)

    return result

def jaso_combine(chosung, jungsung, jongsung=''):
    if chosung and jungsung:
        result = chr((28 * int(jung_list.index(jungsung))) + int(jong_list.index(jongsung)) + (588 * cho_list.index(chosung)) + ord('가'))
    else:
        result = ''.join([chosung, jungsung, jongsung])
    return result

# %%
def tabular_parsing(jaso_list, morpheme, grammar):
    '''

    :param jaso_list: 자소 문자 리스트
    :param morpheme: 형태소 사전
    :param grammar: 품사 태그 접속 사전
    :return: 형태소 분석 결과 리스트
    '''

    ###################################
    # 음절 단위 리스트 변환
    char_list = []
    last_index = len(jaso_list)


    for jaso_idx in range(len(jaso_list), 0, -1):
      # 자소 리스트를 역순으로 탐색하여 음절로 변환
      cur_index = jaso_idx-1

      # 1. 현재 자소가 초성에 포함될 경우만 음절 복원
      if
        # 2. +1 위치의 자소가 중성이 아닌 경우 현재 자소는 종성
        if
          continue
        else:
          # 3. 각 음절 구성 요소에 맞는 자소 할당
          chosung =
          jungsung =
          jongsung =
          # 4. 종성이 있는 경우
          if
            jongsung =

          # 5. 음절 복원
          char =
          char_list.append(char)

          # 6. 기준 인덱스 업데이트
          last_index =
    ######################################

    # 음절 리스트 순서를 역순으로 변환하여 정렬
    # [가, 대, 국, 건] -> [건, 국, 대, 가]
    char_list.reverse()

    # 문법 확인 함수
    def grammar_check(pre_tag, cur_tag, grammar):
      if cur_tag + '+' + pre_tag in grammar:
        return True
      return False

    # Tabular Parsing 재귀 함수
    def parsing(morp_list, pre_tag, char_list, grammar):
      '''

      :param morp_list: Tabular Parsing 결과 저장을 위한 리스트
      :param pre_tag: 접속 정보 확인을 위한 이전 품사 태그
      :param char_list: 음절 리스트
      :param grammar: 품사 태그 접속 사전
      :return: morp_list

      '''
      flag = False
      for index in range(len(char_list), 0, -1):
        # 음절 리스트를 역순으로 추적
        start_index = index-1
        morp = ''.join(char_list[start_index : len(char_list)])

        #################################################################
        # 1. morp가 형태소 사전에 있는 경우, 문법 확인하여 결과에 추가 (재귀 활용)










        #################################################################

      # 끝까지 추적한 후에도 완성되지 않을 경우 현재 결과 삭제
      if not flag:
        morp_list[-1] = morp_list[-1][1:]
      return morp_list

    return parsing([], '', char_list, grammar)

# %%
if __name__ == '__main__':
    morpheme = {"건국": ["NNG"], "국": ["NNG"], "대": ["NNB"], "대가": ["NNG"], "건국대": ["NNP"], "가": ["NNG", "JKS"]}
    grammar = ["NNG+NNG", "NNB+JKS", "NNG+JKS", "NNP+NNG", "NNP+JKS"]

    # input_text = input("Input Sentence : ")
    input_text = "건국대가"
    jaso_list = jaso_split(input_text)
    print(jaso_list)
    print(tabular_parsing(jaso_list, morpheme, grammar))
# Out:
# ['ㄱ', 'ㅓ', 'ㄴ', 'ㄱ', 'ㅜ', 'ㄱ', 'ㄷ', 'ㅐ', 'ㄱ', 'ㅏ']
# [['건국대/NNP', '가/NNG'], ['건국대/NNP', '가/JKS'], ['건국/NNG', '대가/NNG']]
